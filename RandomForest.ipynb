# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/pedrobueno/opt/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in /Users/pedrobueno/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: scipy>=1.0 in /Users/pedrobueno/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: matplotlib>=2.2 in /Users/pedrobueno/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: numpy>=1.15 in /Users/pedrobueno/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/pedrobueno/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/pedrobueno/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/pedrobueno/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/pedrobueno/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/pedrobueno/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: six in /Users/pedrobueno/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/pedrobueno/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2024.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
import seaborn as sns

# %%
def calculate_technical_indicators(df):
    df = df.copy()
    df['SMA_20'] = df['Adj Close'].rolling(window=20).mean()
    df['SMA_50'] = df['Adj Close'].rolling(window=50).mean()
    delta = df['Adj Close'].diff(1)
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)
    avg_gain = gain.rolling(window=14).mean()
    avg_loss = loss.rolling(window=14).mean()
    rs = avg_gain / avg_loss
    df['RSI'] = 100 - (100 / (1 + rs))
    df['EMA_20'] = df['Adj Close'].ewm(span=20, adjust=False).mean()
    return df

# %%
tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'META']
stocks_data = {}
X_train_all = pd.DataFrame()
y_train_all = pd.Series(dtype='float64')
X_test_all = pd.DataFrame()
y_test_all = pd.Series(dtype='float64')

for ticker in tickers:
    print(f"Baixando dados para {ticker}...")
    data = yf.download(ticker, start="2017-01-01", end="2023-12-31")
    if 'Adj Close' in data.columns:
        # Adiciona a coluna do ticker
        data['Ticker'] = ticker
        data = calculate_technical_indicators(data)
        data.dropna(inplace=True)  
        
        stocks_data[ticker] = data
    else:
        print(f"Coluna 'Adj Close' não encontrada para {ticker}")
# Out:
# Baixando dados para AAPL...
# [*********************100%***********************]  1 of 1 completed
# Baixando dados para MSFT...
# [*********************100%***********************]  1 of 1 completed
# Baixando dados para GOOGL...
# [*********************100%***********************]  1 of 1 completed
# Baixando dados para AMZN...
# [*********************100%***********************]  1 of 1 completed
# Baixando dados para META...
# [*********************100%***********************]  1 of 1 completed

# %%
fedfunds = pd.read_csv('/Users/pedrobueno/Desktop/modelos_ML/World Bank/FEDFUNDS.csv')
fedfunds['DATE'] = pd.to_datetime(fedfunds['DATE'])
fedfunds.set_index('DATE', inplace=True)
fedfunds = fedfunds.loc['2017-01-01':'2023-12-31']
fedfunds_daily = pd.DataFrame(index=pd.date_range(start='2017-01-01', end='2023-12-31'))
fedfunds_daily['FEDFUNDS'] = np.nan

# %%
for i, row in fedfunds.iterrows():
    start_date = i
    if i != fedfunds.index[-1]:
        end_date = fedfunds.index[fedfunds.index.get_loc(i) + 1] - pd.DateOffset(days=1)
    else:
        end_date = fedfunds_daily.index[-1]
    fedfunds_daily.loc[start_date:end_date, 'FEDFUNDS'] = row['FEDFUNDS']

# %%
file_path = '/Users/pedrobueno/Desktop/modelos_ML/World Bank/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_3403845.csv'
df_pib = pd.read_csv(file_path, sep=';', skiprows=4)
df_pib_filtered = df_pib.loc[:, '2017':'2023']
df_pib_filtered = df_pib_filtered.T.reset_index()
df_pib_filtered.columns = ['Year', 'GDP']
df_pib_filtered['Date'] = pd.to_datetime(df_pib_filtered['Year'] + '-01-01')
df_pib_daily = pd.DataFrame(index=pd.date_range(start="2017-01-01", end="2024-01-01"))
df_pib_daily['GDP'] = np.nan

# %%
for i, row in df_pib_filtered.iterrows():
    start_date = row['Date']
    if i < len(df_pib_filtered) - 1:
        end_date = df_pib_filtered.loc[i + 1, 'Date'] - pd.DateOffset(days=1)
    else:
        end_date = pd.to_datetime('2024-01-01')
    df_pib_daily.loc[start_date:end_date, 'GDP'] = row['GDP']

# %%
for ticker in tickers:
    X = stocks_data[ticker].copy()

    # Definir o tamanho do treino
    train_size = int(len(X) * 0.8)
    
    # Criar X_train e X_test
    X_train = X.iloc[:train_size]
    X_test = X.iloc[train_size:]
    
    # PIB
    X_train = X_train.join(df_pib_daily['GDP'], how='left')
    X_test = X_test.join(df_pib_daily['GDP'], how='left')
    
    # Taxa de juros
    X_train = X_train.join(fedfunds_daily['FEDFUNDS'], how='left')
    X_test = X_test.join(fedfunds_daily['FEDFUNDS'], how='left')
    
    # Criar y_train e y_test com base em Adj Close deslocado
    y_train = X_train['Adj Close'].shift(-1)  # Prever o próximo dia
    y_test = X_test['Adj Close'].shift(-1)  # Prever o próximo dia
    
    # Remover NaNs do conjunto de treino e teste
    X_train.dropna(inplace=True)
    y_train.dropna(inplace=True)
    
    
    # Ajustar os tamanhos de X_train e y_train para garantir correspondência de índices
    min_len_train = min(len(X_train), len(y_train))
    X_train = X_train.iloc[:min_len_train]
    y_train = y_train.iloc[:min_len_train]

    # Ajustar os tamanhos de X_test e y_test para garantir correspondência de índices
    min_len_test = min(len(X_test), len(y_test))
    X_test = X_test.iloc[:min_len_test]
    y_test = y_test.iloc[:min_len_test]
    
    X_train_all = pd.concat([X_train_all, X_train])
    y_train_all = pd.concat([y_train_all, y_train])
    X_test_all = pd.concat([X_test_all, X_test])
    y_test_all = pd.concat([y_test_all, y_test])

# %%
features = ['Open', 'High', 'Low', 'Close', 'Volume', 'GDP', 'SMA_20', 'SMA_50', 'RSI', 'EMA_20', 'FEDFUNDS']
X_train_all = X_train_all[features + ['Ticker']]
X_test_all = X_test_all[features + ['Ticker']]

# %%
X_train_all_no_ticker = X_train_all.drop(columns=['Ticker'])
X_test_all_no_ticker = X_test_all.drop(columns=['Ticker'])

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_all_no_ticker)
X_test_scaled = scaler.transform(X_test_all_no_ticker)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train_all_no_ticker.columns, index=X_train_all.index)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test_all_no_ticker.columns, index=X_test_all.index)

# %%
X_train_scaled['Ticker'] = X_train_all['Ticker']
X_test_scaled['Ticker'] = X_test_all['Ticker']

# %%
if 'Ticker' in X_train_scaled.columns:
    X_train_scaled_no_ticker = X_train_scaled.drop(columns=['Ticker'])
    X_test_scaled_no_ticker = X_test_scaled.drop(columns=['Ticker'])
else:
    X_train_scaled_no_ticker = X_train_scaled
    X_test_scaled_no_ticker = X_test_scaled

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

rf = RandomForestRegressor(random_state=42)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1, verbose=2)
grid_search.fit(X_train_scaled_no_ticker, y_train_all)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# ...
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   5.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   5.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   5.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   7.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   7.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   5.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   5.1s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   3.7s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   7.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   3.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   3.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   9.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   6.4s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   9.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   9.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   6.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   5.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   5.7s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   2.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   5.7s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   2.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   5.6s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   8.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   7.5s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   3.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   6.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  10.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   9.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   6.6s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   6.4s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   6.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   8.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   9.1s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   5.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   2.8s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   5.7s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   3.9s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   7.9s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  11.8s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  10.7s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   7.1s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   6.9s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  10.2s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  10.9s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   6.2s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   6.1s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   9.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   9.4s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   6.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  14.1s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   9.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   4.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   9.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   9.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   9.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  13.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  14.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   9.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   4.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   9.2s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   4.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   9.1s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  13.6s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  13.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.9s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  12.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  17.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  17.6s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  11.6s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.7s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.5s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  10.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  15.9s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  15.6s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  10.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   5.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   4.9s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   9.8s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   6.8s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  13.5s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  19.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  18.9s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.8s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.8s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  11.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  17.1s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  17.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  10.8s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   5.1s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.2s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  15.4s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  16.3s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  10.0s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   6.8s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   6.7s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  20.7s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  12.5s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  19.3s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  16.7s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  12.2s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.7s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.7s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  17.0s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  16.6s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.1s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   5.1s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  15.7s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  10.3s
# [CV] END bootstrap=False, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  12.4s

# %%
model = grid_search.best_estimator_

# %%
print("Melhores parâmetros encontrados:", grid_search.best_params_)
# Out:
# Melhores parâmetros encontrados: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 300}

# %%
cv_results = grid_search.cv_results_

# %%
print("Resultados da validação cruzada:")
for mean_score, std_score, params in zip(cv_results['mean_test_score'], cv_results['std_test_score'], cv_results['params']):
    print(f"Parâmetros: {params}")
    print(f"Média do erro (neg_mean_squared_error): {mean_score:.4f}")
    print(f"Desvio padrão do erro: {std_score:.4f}")
    print("-" * 50)
# Out:
# Resultados da validação cruzada:
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -38.7507
# Desvio padrão do erro: 38.2918
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -38.4359
# Desvio padrão do erro: 37.9370
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -38.6290
# Desvio padrão do erro: 38.2642
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -38.5612
# Desvio padrão do erro: 37.8018
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -38.1486
# Desvio padrão do erro: 37.4118
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -38.3414
# Desvio padrão do erro: 37.7204
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -37.6416
# Desvio padrão do erro: 36.3301
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -37.3517
# Desvio padrão do erro: 36.0243
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -37.5999
# Desvio padrão do erro: 36.5098
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -37.4159
# Desvio padrão do erro: 36.4654
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -37.2205
# Desvio padrão do erro: 36.3178
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -37.3491
# Desvio padrão do erro: 36.5474
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -37.2971
# Desvio padrão do erro: 36.2498
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -37.0360
# Desvio padrão do erro: 35.9283
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -37.2256
# Desvio padrão do erro: 36.2378
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -37.0554
# Desvio padrão do erro: 35.9845
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -36.5740
# Desvio padrão do erro: 35.3799
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -36.6523
# Desvio padrão do erro: 35.5372
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -35.2529
# Desvio padrão do erro: 33.4276
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -35.1190
# Desvio padrão do erro: 33.3401
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -35.1967
# Desvio padrão do erro: 33.4146
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -35.2529
# Desvio padrão do erro: 33.4276
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -35.1190
# Desvio padrão do erro: 33.3401
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -35.1967
# Desvio padrão do erro: 33.4146
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -35.1928
# Desvio padrão do erro: 33.3458
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -35.0596
# Desvio padrão do erro: 33.2530
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -34.9795
# Desvio padrão do erro: 33.1120
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -39.2530
# Desvio padrão do erro: 38.8513
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -38.9509
# Desvio padrão do erro: 38.4719
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -39.0068
# Desvio padrão do erro: 38.6411
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -38.6656
# Desvio padrão do erro: 37.8309
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -38.3441
# Desvio padrão do erro: 37.5142
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -38.5391
# Desvio padrão do erro: 37.8433
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -37.9648
# Desvio padrão do erro: 36.8890
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -37.5517
# Desvio padrão do erro: 36.4114
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -37.7153
# Desvio padrão do erro: 36.7466
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -37.5775
# Desvio padrão do erro: 36.6901
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -37.3110
# Desvio padrão do erro: 36.3787
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -37.4720
# Desvio padrão do erro: 36.6146
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -37.4054
# Desvio padrão do erro: 36.3741
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -37.1207
# Desvio padrão do erro: 36.1112
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -37.2917
# Desvio padrão do erro: 36.3084
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -36.5185
# Desvio padrão do erro: 34.9847
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -36.4075
# Desvio padrão do erro: 35.0261
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -36.5306
# Desvio padrão do erro: 35.2971
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -35.2420
# Desvio padrão do erro: 33.4422
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -35.1960
# Desvio padrão do erro: 33.4294
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -35.2602
# Desvio padrão do erro: 33.4717
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -35.2420
# Desvio padrão do erro: 33.4422
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -35.1960
# Desvio padrão do erro: 33.4294
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -35.2602
# Desvio padrão do erro: 33.4717
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -35.1353
# Desvio padrão do erro: 33.2629
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -35.0428
# Desvio padrão do erro: 33.1861
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -35.0554
# Desvio padrão do erro: 33.1660
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -39.0423
# Desvio padrão do erro: 38.2985
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -38.7919
# Desvio padrão do erro: 38.1063
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -38.8888
# Desvio padrão do erro: 38.4027
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -38.6428
# Desvio padrão do erro: 37.7463
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -38.2033
# Desvio padrão do erro: 37.2960
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -38.4419
# Desvio padrão do erro: 37.7286
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -37.8790
# Desvio padrão do erro: 36.6789
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -37.4757
# Desvio padrão do erro: 36.2484
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -37.6643
# Desvio padrão do erro: 36.6601
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -37.6457
# Desvio padrão do erro: 36.7580
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -37.3582
# Desvio padrão do erro: 36.4317
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -37.4978
# Desvio padrão do erro: 36.6196
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -37.5099
# Desvio padrão do erro: 36.5496
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -37.2099
# Desvio padrão do erro: 36.2124
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -37.3083
# Desvio padrão do erro: 36.3465
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -36.6814
# Desvio padrão do erro: 35.2663
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -36.4781
# Desvio padrão do erro: 35.1493
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -36.5865
# Desvio padrão do erro: 35.3838
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -35.2422
# Desvio padrão do erro: 33.4421
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -35.1888
# Desvio padrão do erro: 33.4165
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -35.2563
# Desvio padrão do erro: 33.4645
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -35.2422
# Desvio padrão do erro: 33.4421
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -35.1888
# Desvio padrão do erro: 33.4165
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -35.2563
# Desvio padrão do erro: 33.4645
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -35.1353
# Desvio padrão do erro: 33.2629
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -35.0432
# Desvio padrão do erro: 33.1868
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -35.0556
# Desvio padrão do erro: 33.1663
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -39.0288
# Desvio padrão do erro: 38.2734
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -38.7862
# Desvio padrão do erro: 38.0945
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -38.8859
# Desvio padrão do erro: 38.3952
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -38.6428
# Desvio padrão do erro: 37.7463
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -38.2033
# Desvio padrão do erro: 37.2960
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -38.4424
# Desvio padrão do erro: 37.7288
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -37.8790
# Desvio padrão do erro: 36.6789
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -37.4757
# Desvio padrão do erro: 36.2484
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -37.6643
# Desvio padrão do erro: 36.6601
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -37.6457
# Desvio padrão do erro: 36.7580
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -37.3582
# Desvio padrão do erro: 36.4317
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -37.4978
# Desvio padrão do erro: 36.6196
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -37.5099
# Desvio padrão do erro: 36.5496
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -37.2099
# Desvio padrão do erro: 36.2124
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -37.3083
# Desvio padrão do erro: 36.3465
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -36.6814
# Desvio padrão do erro: 35.2663
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -36.4781
# Desvio padrão do erro: 35.1493
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -36.5865
# Desvio padrão do erro: 35.3838
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -35.2422
# Desvio padrão do erro: 33.4421
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -35.1888
# Desvio padrão do erro: 33.4165
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -35.2563
# Desvio padrão do erro: 33.4645
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -35.2422
# Desvio padrão do erro: 33.4421
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -35.1888
# Desvio padrão do erro: 33.4165
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -35.2563
# Desvio padrão do erro: 33.4645
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -35.1353
# Desvio padrão do erro: 33.2629
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -35.0432
# Desvio padrão do erro: 33.1868
# --------------------------------------------------
# Parâmetros: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -35.0556
# Desvio padrão do erro: 33.1663
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -57.6210
# Desvio padrão do erro: 57.2064
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -57.6268
# Desvio padrão do erro: 57.1963
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -57.5353
# Desvio padrão do erro: 57.1065
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -56.6014
# Desvio padrão do erro: 55.9132
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -56.5401
# Desvio padrão do erro: 55.8133
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -56.5914
# Desvio padrão do erro: 55.8645
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -57.1924
# Desvio padrão do erro: 56.3575
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -57.1559
# Desvio padrão do erro: 56.3419
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -57.1664
# Desvio padrão do erro: 56.3842
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -56.2503
# Desvio padrão do erro: 56.6811
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -56.1838
# Desvio padrão do erro: 56.5226
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -56.1824
# Desvio padrão do erro: 56.4746
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -56.1546
# Desvio padrão do erro: 56.3494
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -56.1338
# Desvio padrão do erro: 56.2870
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -56.1773
# Desvio padrão do erro: 56.4406
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -55.7217
# Desvio padrão do erro: 55.8590
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -55.7242
# Desvio padrão do erro: 55.8562
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -55.7367
# Desvio padrão do erro: 55.8695
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -46.6516
# Desvio padrão do erro: 42.6191
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -46.6633
# Desvio padrão do erro: 42.6313
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -46.6637
# Desvio padrão do erro: 42.6368
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -46.6516
# Desvio padrão do erro: 42.6191
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -46.6633
# Desvio padrão do erro: 42.6313
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -46.6637
# Desvio padrão do erro: 42.6368
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -45.8078
# Desvio padrão do erro: 41.9121
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -45.8075
# Desvio padrão do erro: 41.9110
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -45.8199
# Desvio padrão do erro: 41.9148
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -59.6088
# Desvio padrão do erro: 56.7571
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -59.4377
# Desvio padrão do erro: 56.7299
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -59.4891
# Desvio padrão do erro: 56.8853
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -58.2652
# Desvio padrão do erro: 55.9726
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -58.2169
# Desvio padrão do erro: 56.0992
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -58.2525
# Desvio padrão do erro: 56.1902
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -58.4818
# Desvio padrão do erro: 56.6251
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -58.4752
# Desvio padrão do erro: 56.5994
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -58.5056
# Desvio padrão do erro: 56.6751
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -57.9449
# Desvio padrão do erro: 55.6772
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -57.9866
# Desvio padrão do erro: 55.6821
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -58.0114
# Desvio padrão do erro: 55.7115
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -58.1246
# Desvio padrão do erro: 55.9133
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -58.0807
# Desvio padrão do erro: 55.8678
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -58.1146
# Desvio padrão do erro: 55.9240
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -57.3101
# Desvio padrão do erro: 55.6759
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -57.3215
# Desvio padrão do erro: 55.6456
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -57.2943
# Desvio padrão do erro: 55.6450
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -47.6185
# Desvio padrão do erro: 42.3811
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -47.6363
# Desvio padrão do erro: 42.4012
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -47.6241
# Desvio padrão do erro: 42.3902
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -47.6185
# Desvio padrão do erro: 42.3811
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -47.6363
# Desvio padrão do erro: 42.4012
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -47.6241
# Desvio padrão do erro: 42.3902
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -46.7341
# Desvio padrão do erro: 41.7030
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -46.6992
# Desvio padrão do erro: 41.6980
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -46.6986
# Desvio padrão do erro: 41.6861
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -59.8106
# Desvio padrão do erro: 57.1366
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -59.5575
# Desvio padrão do erro: 56.8228
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -59.5277
# Desvio padrão do erro: 56.8014
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -58.0269
# Desvio padrão do erro: 55.8842
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -58.0545
# Desvio padrão do erro: 55.9537
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -58.0435
# Desvio padrão do erro: 55.9536
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -58.5723
# Desvio padrão do erro: 56.6052
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -58.5491
# Desvio padrão do erro: 56.5986
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -58.5679
# Desvio padrão do erro: 56.6264
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -57.9682
# Desvio padrão do erro: 55.6624
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -57.9539
# Desvio padrão do erro: 55.6732
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -57.9808
# Desvio padrão do erro: 55.6974
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -58.0469
# Desvio padrão do erro: 55.9139
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -57.9716
# Desvio padrão do erro: 55.8237
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -58.0150
# Desvio padrão do erro: 55.8433
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -57.3225
# Desvio padrão do erro: 55.6977
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -57.3482
# Desvio padrão do erro: 55.6926
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -57.2491
# Desvio padrão do erro: 55.5651
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -47.6185
# Desvio padrão do erro: 42.3811
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -47.6363
# Desvio padrão do erro: 42.4012
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -47.6241
# Desvio padrão do erro: 42.3902
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -47.6185
# Desvio padrão do erro: 42.3811
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -47.6363
# Desvio padrão do erro: 42.4012
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -47.6241
# Desvio padrão do erro: 42.3902
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -46.7341
# Desvio padrão do erro: 41.7030
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -46.6992
# Desvio padrão do erro: 41.6980
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -46.6986
# Desvio padrão do erro: 41.6861
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -59.8106
# Desvio padrão do erro: 57.1366
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -59.5575
# Desvio padrão do erro: 56.8228
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -59.5277
# Desvio padrão do erro: 56.8014
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -58.0269
# Desvio padrão do erro: 55.8842
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -58.0545
# Desvio padrão do erro: 55.9537
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -58.0435
# Desvio padrão do erro: 55.9536
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -58.5723
# Desvio padrão do erro: 56.6052
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -58.5491
# Desvio padrão do erro: 56.5986
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -58.5679
# Desvio padrão do erro: 56.6264
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -57.9682
# Desvio padrão do erro: 55.6624
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -57.9539
# Desvio padrão do erro: 55.6732
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -57.9808
# Desvio padrão do erro: 55.6974
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -58.0469
# Desvio padrão do erro: 55.9139
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -57.9716
# Desvio padrão do erro: 55.8237
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -58.0150
# Desvio padrão do erro: 55.8433
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -57.3225
# Desvio padrão do erro: 55.6977
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -57.3482
# Desvio padrão do erro: 55.6926
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -57.2491
# Desvio padrão do erro: 55.5651
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -47.6185
# Desvio padrão do erro: 42.3811
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -47.6363
# Desvio padrão do erro: 42.4012
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -47.6241
# Desvio padrão do erro: 42.3902
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -47.6185
# Desvio padrão do erro: 42.3811
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -47.6363
# Desvio padrão do erro: 42.4012
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -47.6241
# Desvio padrão do erro: 42.3902
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# Média do erro (neg_mean_squared_error): -46.7341
# Desvio padrão do erro: 41.7030
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# Média do erro (neg_mean_squared_error): -46.6992
# Desvio padrão do erro: 41.6980
# --------------------------------------------------
# Parâmetros: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 300}
# Média do erro (neg_mean_squared_error): -46.6986
# Desvio padrão do erro: 41.6861
# --------------------------------------------------

# %%
print("Melhor score (neg_mean_squared_error):", grid_search.best_score_)
# Out:
# Melhor score (neg_mean_squared_error): -34.979526778864475

# %%
y_pred_train = model.predict(X_train_scaled_no_ticker)
y_pred_test = model.predict(X_test_scaled_no_ticker)

# %%
y_test_all = y_test_all.dropna()
y_pred_test = pd.Series(y_pred_test).dropna()

# %%
mse_train = mean_squared_error(y_train_all, y_pred_train)
mae_train = mean_absolute_error(y_train_all, y_pred_train)
r2_train = r2_score(y_train_all, y_pred_train)

# %%
min_len_test = min(len(y_test_all), len(y_pred_test))
y_test_all = y_test_all.iloc[:min_len_test]
y_pred_test = y_pred_test[:min_len_test]

# %%
mse_test = mean_squared_error(y_test_all, y_pred_test)
mae_test = mean_absolute_error(y_test_all, y_pred_test)
r2_test = r2_score(y_test_all, y_pred_test)

# %%
print(f"Train - Mean Squared Error: {mse_train}")
print(f"Train - Mean Absolute Error: {mae_train}")
print(f"Train - R2 Score: {r2_train}")

print(f"Test - Mean Squared Error: {mse_test}")
print(f"Test - Mean Absolute Error: {mae_test}")
print(f"Test - R2 Score: {r2_test}")
# Out:
# Train - Mean Squared Error: 5.960018493936927
# Train - Mean Absolute Error: 1.4442551340202023
# Train - R2 Score: 0.9989781472716478
# Test - Mean Squared Error: 146.25672827124288
# Test - Mean Absolute Error: 5.826336384349513
# Test - R2 Score: 0.977783118186241

# %%
if 'Ticker' not in X_test_all.columns:
    X_test_all = X_test_all.reset_index(level=0)  
    X_test_all.rename(columns={'level_0': 'Ticker'}, inplace=True)

# %%
print(X_train_all.head())
print(X_test_all.head())
# Out:
#                  Open       High        Low      Close     Volume  \
# Date
# 2017-03-15  34.852501  35.187500  34.757500  35.115002  102767200
# 2017-03-16  35.180000  35.255001  35.064999  35.172501   76928000
# 2017-03-17  35.250000  35.250000  34.972500  34.997501  175540000
# 2017-03-20  35.099998  35.375000  35.057499  35.365002   86168000
# 2017-03-21  35.527500  35.700001  34.932499  34.959999  158119600
#
#                      GDP     SMA_20     SMA_50        RSI     EMA_20  \
# Date
# 2017-03-15  1.961210e+13  32.128863  30.034887  72.929510  31.925748
# 2017-03-16  1.961210e+13  32.189156  30.151474  73.241600  32.004332
# 2017-03-17  1.961210e+13  32.243163  30.265404  66.813883  32.059913
# 2017-03-20  1.961210e+13  32.309973  30.383443  71.265922  32.142789
# 2017-03-21  1.961210e+13  32.346521  30.487913  50.268032  32.181857
#
#             FEDFUNDS Ticker
# Date
# 2017-03-15      0.79   AAPL
# 2017-03-16      0.79   AAPL
# 2017-03-17      0.79   AAPL
# 2017-03-20      0.79   AAPL
# 2017-03-21      0.79   AAPL
#                   Open        High         Low       Close    Volume  \
# Date
# 2022-08-19  173.029999  173.740005  171.309998  171.520004  70346300
# 2022-08-22  169.690002  169.860001  167.139999  167.570007  69026800
# 2022-08-23  167.080002  168.710007  166.649994  167.229996  54147100
# 2022-08-24  167.320007  168.110001  166.250000  167.529999  53841500
# 2022-08-25  168.779999  170.139999  168.350006  170.029999  51218200
#
#                      GDP      SMA_20      SMA_50        RSI      EMA_20  \
# Date
# 2022-08-19  2.574411e+13  163.393623  149.504337  72.085598  163.853133
# 2022-08-22  2.574411e+13  164.127105  150.001387  65.186632  164.032235
# 2022-08-23  2.574411e+13  164.910439  150.600553  53.351298  164.162254
# 2022-08-24  2.574411e+13  165.452310  151.309358  54.916847  164.308147
# 2022-08-25  2.574411e+13  166.090156  152.050232  60.588255  164.675633
#
#             FEDFUNDS Ticker
# Date
# 2022-08-19      2.33   AAPL
# 2022-08-22      2.33   AAPL
# 2022-08-23      2.33   AAPL
# 2022-08-24      2.33   AAPL
# 2022-08-25      2.33   AAPL

# %%
predicted_values = pd.DataFrame()
for ticker in tickers:
    X_test_ticker = X_test_all[X_test_all['Ticker'] == ticker]
    y_pred_test_ticker = model.predict(scaler.transform(X_test_ticker[features]))
    
    
    temp_df = pd.DataFrame({
        'Date': X_test_ticker.index,
        'Predicted': y_pred_test_ticker,
        'Ticker': ticker  # Adiciona a coluna 'Ticker'
    })
    
    predicted_values = pd.concat([predicted_values, temp_df], ignore_index=True)
predicted_values.set_index('Date', inplace=True)

# %%
all_stocks_data = pd.concat(stocks_data.values(), ignore_index=True)
for ticker in stocks_data:
    stocks_data[ticker]['Date'] = stocks_data[ticker].index
all_stocks_data = pd.concat(stocks_data.values(), ignore_index=True)

# %%
merged_data = pd.merge(
    predicted_values.reset_index(),  
    all_stocks_data[['Date', 'Adj Close', 'Ticker']],
    on=['Date', 'Ticker'],
    how='inner'
)
merged_data.rename(columns={'Adj Close': 'Real'}, inplace=True)

# %%
for ticker in tickers:
    plt.figure(figsize=(12, 6))
    
    # Filtrar os dados do ticker atual
    merged_ticker_data = merged_data[merged_data['Ticker'] == ticker]
    
    # Gráfico de linha para valores reais e previstos
    sns.lineplot(x=merged_ticker_data['Date'], y=merged_ticker_data['Real'], label='Valor Real', color='blue')
    sns.lineplot(x=merged_ticker_data['Date'], y=merged_ticker_data['Predicted'], label='Valor Previsto', color='orange')

    # Configurar gráfico
    plt.title(f'Valores Reais vs. Valores Previstos - {ticker}')
    plt.xlabel('Data')
    plt.ylabel('Preço de Fechamento (USD)')
    plt.legend()
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    
    plt.show()

# %%
for ticker in tickers:
    print(f"\nResultados para {ticker}:")
    results = merged_data[merged_data['Ticker'] == ticker][['Date', 'Ticker', 'Real', 'Predicted']].head(10)
    print(results)
# Out:
# Resultados para AAPL:
#         Date Ticker        Real   Predicted
# 0 2022-08-19   AAPL  169.640396  170.584577
# 1 2022-08-22   AAPL  165.733704  167.628340
# 2 2022-08-23   AAPL  165.397430  168.006101
# 3 2022-08-24   AAPL  165.694138  167.868852
# 4 2022-08-25   AAPL  168.166748  168.648588
# 5 2022-08-26   AAPL  161.826996  162.277402
# 6 2022-08-29   AAPL  159.611526  161.294224
# 7 2022-08-30   AAPL  157.168594  158.024719
# 8 2022-08-31   AAPL  155.497131  157.223106
# 9 2022-09-01   AAPL  156.229004  156.214633
#
# Resultados para MSFT:
#           Date Ticker        Real   Predicted
# 343 2022-08-19   MSFT  281.300568  279.331943
# 344 2022-08-22   MSFT  273.042938  276.349421
# 345 2022-08-23   MSFT  271.755096  274.174496
# 346 2022-08-24   MSFT  271.116119  273.593969
# 347 2022-08-25   MSFT  274.124268  274.507062
# 348 2022-08-26   MSFT  263.546631  269.797550
# 349 2022-08-29   MSFT  260.735107  258.365907
# 350 2022-08-30   MSFT  258.513397  256.488030
# 351 2022-08-31   MSFT  257.038818  257.418935
# 352 2022-09-01   MSFT  255.986954  256.524950
#
# Resultados para GOOGL:
#           Date Ticker        Real   Predicted
# 686 2022-08-19  GOOGL  116.920486  116.477977
# 687 2022-08-22  GOOGL  113.957825  113.456940
# 688 2022-08-23  GOOGL  113.578766  111.878884
# 689 2022-08-24  GOOGL  113.409180  111.514968
# 690 2022-08-25  GOOGL  116.361870  115.839929
# 691 2022-08-26  GOOGL  110.067451  108.126300
# 692 2022-08-29  GOOGL  109.149727  106.501494
# 693 2022-08-30  GOOGL  108.670914  106.315292
# 694 2022-08-31  GOOGL  107.952690  105.916730
# 695 2022-09-01  GOOGL  109.468941  106.451163
#
# Resultados para AMZN:
#            Date Ticker        Real   Predicted
# 1029 2022-08-19   AMZN  138.229996  138.415144
# 1030 2022-08-22   AMZN  133.220001  131.003804
# 1031 2022-08-23   AMZN  133.619995  132.284846
# 1032 2022-08-24   AMZN  133.800003  132.747567
# 1033 2022-08-25   AMZN  137.279999  136.252275
# 1034 2022-08-26   AMZN  130.750000  129.728582
# 1035 2022-08-29   AMZN  129.789993  127.330944
# 1036 2022-08-30   AMZN  128.729996  127.581583
# 1037 2022-08-31   AMZN  126.769997  125.869672
# 1038 2022-09-01   AMZN  127.820000  123.529408
#
# Resultados para META:
#            Date Ticker        Real   Predicted
# 1372 2022-08-19   META  167.455826  167.920989
# 1373 2022-08-22   META  162.560547  162.958965
# 1374 2022-08-23   META  160.626373  162.036660
# 1375 2022-08-24   META  162.769928  162.342432
# 1376 2022-08-25   META  168.273331  168.620332
# 1377 2022-08-26   META  161.294373  162.186995
# 1378 2022-08-29   META  158.692184  161.695408
# 1379 2022-08-30   META  156.688248  158.111153
# 1380 2022-08-31   META  162.440903  162.692032
# 1381 2022-09-01   META  164.863617  163.666733

# %%
for ticker in tickers:
    plt.figure(figsize=(14, 7))
    
    # Filtrar os dados para o ticker atual
    ticker_data = all_stocks_data[all_stocks_data['Ticker'] == ticker]
    
    # Plotar o valor de fechamento
    plt.plot(ticker_data.index, ticker_data['Adj Close'], label='Preço de Fechamento')
    
    # Adicionar médias móveis
    plt.plot(ticker_data.index, ticker_data['SMA_20'], label='SMA 20', linestyle='--')
    plt.plot(ticker_data.index, ticker_data['SMA_50'], label='SMA 50', linestyle='--')

    # Customizar gráfico
    plt.title(f'Análise do {ticker}')
    plt.xlabel('Data')
    plt.ylabel('Preço de Fechamento')
    plt.legend()
    plt.grid()
    plt.xticks(rotation=45)
    
    # Mostrar o gráfico
    plt.show()

# %%
correlation_matrix = X_train_all.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Mapa de Correlação entre as Features')
plt.show()
